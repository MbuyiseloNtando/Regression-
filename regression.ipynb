# %%
import pandas as pd

# %%
#loading data 
df = pd.read_csv("https://raw.githubusercontent.com/artinmohajeri/Car-Data-Analisys-Pandas/main/cars.csv " )
df
# Out:
#           Make                     Model   Type  Origin DriveTrain      MSRP  \
# 0    Chevrolet              Silverado SS  Truck     USA        All  $40,340
# 1          GMC  Sierra Extended Cab 1500  Truck     USA       Rear  $25,717
# 2         Ford         Excursion 6.8 XLT    SUV     USA        All  $41,475
# 3       Nissan         Titan King Cab XE  Truck    Asia        All  $26,650
# 4    Chevrolet            Avalanche 1500  Truck     USA        All  $36,100
# ..         ...                       ...    ...     ...        ...       ...
# 427       MINI                    Cooper  Sedan  Europe      Front  $16,999
# 428        NaN                       NaN    NaN     NaN        NaN       NaN
# 429        NaN                       NaN    NaN     NaN        NaN       NaN
# 430        NaN                       NaN    NaN     NaN        NaN       NaN
# 431        NaN                       NaN    NaN     NaN        NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    object
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 50.8+ KB

# %% [markdown]
# Cleaning the data frame

# %%
df.isna().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
#Dropping null entries 
df.dropna(inplace = True)

# %%
df.info()
df. head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 426 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         426 non-null    object
#  1   Model        426 non-null    object
#  2   Type         426 non-null    object
#  3   Origin       426 non-null    object
#  4   DriveTrain   426 non-null    object
#  5   MSRP         426 non-null    object
#  6   Invoice      426 non-null    object
#  7   EngineSize   426 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   426 non-null    object
#  10  MPG_City     426 non-null    float64
#  11  MPG_Highway  426 non-null    float64
#  12  Weight       426 non-null    float64
#  13  Wheelbase    426 non-null    float64
#  14  Length       426 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 53.2+ KB
#         Make                     Model   Type Origin DriveTrain      MSRP  \
# ...

# %%
#Removing $, commas and any spaces from numerical columns with object entries 
dollar_cols = [] 
comma_cols = [] 
space_cols = [] 
for col in df.columns:
    if df[col].dtype=="object":
        if df[col].str.contains("$").any():
            dollar_cols.append(col)
        if df[col].str.contains(",").any():
            comma_cols.append(col)
        if df[col].str.contains("Horsepower").any():
            space_cols.append(col)
        
for col in dollar_cols:
    df[col]=df[col].str.replace("$","")
for col in comma_cols:
    df[col] =df[col].str.replace(",", "") 
for col in space_cols:
    df[col] = df[col].str.replace("Horsepower"," 150")

# %%
df. tail()
# Out:
#           Make                            Model    Type  Origin DriveTrain  \
# 423  Chevrolet                Aveo LS 4dr hatch   Sedan     USA      Front
# 424     Toyota       MR2 Spyder convertible 2dr  Sports    Asia       Rear
# 425       Jeep  Wrangler Sahara convertible 2dr     SUV     USA        All
# 426       MINI                         Cooper S   Sedan  Europe      Front
# 427       MINI                           Cooper   Sedan  Europe      Front
#
#        MSRP Invoice  EngineSize  Cylinders Horsepower  MPG_City  MPG_Highway  \
# 423  12585   11802          1.6        4.0        103      28.0         34.0
# 424  25130   22787          1.8        4.0        138      26.0         32.0
# 425  25520   23275          4.0        6.0        190      16.0         19.0
# 426  19999   18137          1.6        4.0        163      25.0         34.0
# 427  16999   15437          1.6        4.0        150      28.0         37.0
#
#      Weight  Wheelbase  Length
# ...

# %%
#Converting from object to numerical data types
df = df.astype({'MSRP':'int', 'Invoice':'int', 'Horsepower':'int'})

# %%
import matplotlib.pyplot as plt

# %%
 #plot categorical data with target entries
fig=plt.figure(figsize=(15,5))
fig.suptitle('visualizing categorical data columns', fontsize=20)

plt.subplot(1,3,1)
plt.bar(df['Type'], df['MSRP'],color= 'green')
plt.xlabel('Type')
plt.ylabel('MSRP')

plt.subplot(1,3,2)
plt.bar(df['Origin'], df['MSRP'],color= 'red')
plt.xlabel('Origin')
plt.ylabel('MSRP')

plt.subplot(1,3,3)
plt.bar(df['DriveTrain'], df['MSRP'], color='blue') 
plt.xlabel('Drive train') 
plt.ylabel('MSRP')
# Out:
# Text(0, 0.5, 'MSRP')

# %%
import seaborn as sns

# %%
sns.barplot(x=df['Cylinders'],y= df['MSRP'])
# Out:
# <Axes: xlabel='Cylinders', ylabel='MSRP'>

# %%
sns.barplot(x=df.EngineSize, y=df.MSRP).tick_params(axis='x', rotation=90)

# %%
sns.scatterplot(x=df.Cylinders, y=df.MSRP)
# Out:
# <Axes: xlabel='Cylinders', ylabel='MSRP'>

# %% [markdown]
# Checking categorical features

# %%
#Dropping Make column
df.drop(['Make'], axis=1, inplace =True)

# %%
#Dropping Model column
df.drop(['Model'], axis=1, inplace = True)

# %%
df.Type.value_counts()
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     47
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Encoding Type entries 
df.replace({'Type': {'Sedan' :2,'SUV':3,'Sports':4,'Wagon':5,'Truck':6,'Hybrid' :7}} , inplace=True)

# %%
df.Origin.value_counts()
# Out:
# Origin
# Asia      156
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
#Encoding Origin entiries
df.replace({'Origin' :{'Asia' :2,'USA' :3,'Europe':4}}, inplace =True )

# %%
df.DriveTrain.value_counts()
# Out:
# DriveTrain
# Front    226
# Rear     108
# All       92
# Name: count, dtype: int64

# %%
#Encoding DriveTrain entries
df.replace({'DriveTrain':{'Front':2, 'Rear':3, 'All':4}}, inplace=True)

# %%
#Descriptive statistics
df.describe()
# Out:
#              Type      Origin  DriveTrain           MSRP        Invoice  \
# count  426.000000  426.000000  426.000000     426.000000     426.000000
# mean     2.833333    2.922535    2.685446   32804.549296   30040.654930
# std      1.265996    0.806508    0.805642   19472.460825   17679.430122
# min      2.000000    2.000000    2.000000   10280.000000    9875.000000
# 25%      2.000000    2.000000    2.000000   20324.750000   18836.000000
# 50%      2.000000    3.000000    2.000000   27807.500000   25521.500000
# 75%      3.000000    4.000000    3.000000   39225.000000   35754.750000
# max      7.000000    4.000000    4.000000  192465.000000  173560.000000
#
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  426.000000  426.000000  426.000000  426.000000   426.000000
# mean     3.205634    5.807512  215.960094   20.070423    26.854460
# std      1.103520    1.558443   71.895550    5.248616     5.752335
# ...

# %%
#Correlation amounts columns
df.corr()
# Out:
#                  Type    Origin  DriveTrain      MSRP   Invoice  EngineSize  \
# Type         1.000000 -0.035719    0.322203  0.081774  0.076875    0.159664
# Origin      -0.035719  1.000000    0.194171  0.475443  0.483467    0.170485
# DriveTrain   0.322203  0.194171    1.000000  0.322683  0.317110    0.357966
# MSRP         0.081774  0.475443    0.322683  1.000000  0.999132    0.573238
# Invoice      0.076875  0.483467    0.317110  0.999132  1.000000    0.566019
# EngineSize   0.159664  0.170485    0.357966  0.573238  0.566019    1.000000
# Cylinders    0.071952  0.280144    0.330218  0.649742  0.645226    0.908002
# Horsepower   0.126286  0.342838    0.351208  0.827465  0.824227    0.792637
# MPG_City    -0.042139 -0.264404   -0.433230 -0.475916 -0.471304   -0.717860
# MPG_Highway -0.173288 -0.168282   -0.508991 -0.440523 -0.435452   -0.725901
# Weight       0.150021  0.201625    0.445071  0.447987  0.441916    0.808707
# ...

# %%
plt.figure(figsize= (10,7))
sns.heatmap(df.corr(), cmap='coolwarm', annot=True) 
plt.title('Correlation Between Columns')
# Out:
# Text(0.5, 1.0, 'Correlation Between Columns')

# %% [markdown]
# Creating the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#spilitting data and target
x= df.drop(['MSRP'], axis=1)
y=df['MSRP']

# %%
#train =80, test=20
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.2, random_state=0)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# array([ 41522.41227889,  48689.253309  ,  38149.31292636,  28598.30392523,
#         44917.28782438,  21439.30822451,  21930.01079907,  56393.11458285,
#         33892.47331172,  14734.93129202,  31313.77431098,  52594.16488235,
#         26364.06999924,  14348.01935312,  18334.01894053,  19023.11283624,
#        189561.40795635,  37783.23654514,  13151.49662143,  31487.86570587,
#         12947.89321817,  27700.8118579 ,  25873.82992335,  24377.51887899,
#         51383.92608768,  62676.06582462,  25202.15797381,  50578.08413392,
#         25951.42981197,  16147.69625029,  26738.029708  ,  18888.0437629 ,
#         56983.53209013,  17836.66506969,  30092.91280356,  26409.21901041,
#         26188.98312544,  21273.46204283,  14019.5833187 ,  33208.19476231,
#         20232.98663247,  31183.59505163,  19864.50845428,  22443.4892491 ,
#         45362.30411034,  11861.40398584,  28197.17413416,  21468.92450364,
# ...

# %%
print ("The model intercept is :", model.intercept_)
print (model.coef_)
# Out:
# The model intercept is : 84.86615802374945
# [ 4.88746741e+01 -1.99727982e+02  1.48537919e+02  1.08957546e+00
#   2.52302479e+02 -2.02933657e+01  4.45554925e-01 -4.40963655e+01
#   5.65785586e+01  1.93700695e-01 -3.20726278e+01  7.40912042e+00]

# %%
compare= pd.DataFrame({'Actual': y_test, 'predict': y_pred})
compare. head()
# Out:
#      Actual       predict
# 274   42490  41522.412279
# 159   48170  48689.253309
# 54    38380  38149.312926
# 309   28370  28598.303925
# 10    46265  44917.287824

# %%
from sklearn import metrics
import numpy as np

# %%
#Error evaluation 
print ('Mean Absolute Error:', metrics.mean_absolute_error (y_test, y_pred))
print ('Mean Squard Error:', metrics.mean_squared_error (y_test, y_pred))
print ('Root Mean Squard Error:', np.sqrt (metrics.mean_squared_error (y_test, y_pred)))
print ('R2 Score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 467.4462429074419
# Mean Squard Error: 448645.4860525227
# Root Mean Squard Error: 669.8100372885754
# R2 Score: 0.9991451003013488

# %%
sns.regplot(x=y_pred, y=y_test)
plt.xlabel ('Predicted MSRP')
plt.ylabel ('Actual MSRP')
plt.title('Actual VS predicted price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# R^2 approx 0.99, this is a good model
